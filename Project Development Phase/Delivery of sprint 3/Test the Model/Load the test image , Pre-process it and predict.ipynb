# %%
import cv2
from matplotlib import pyplot as plt
import os
import numpy as np
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.models import load_model

# %%
filepath = 'C:/Users/shadr/OneDrive/Documents/IBM/asl_model_84_54.h5'
model = load_model(filepath)
print(model)
print("Model Loaded Successfully")
# Out:
# <keras.engine.sequential.Sequential object at 0x0000023AADE96FA0>
# Model Loaded Successfully

# %%
image= cv2.imread('C:/Users/shadr/OneDrive/Documents/IBM/Dataset/test_set/D/14.png')

# %%
test_image = cv2.resize(image, (64,64)) # load image
test_image = img_to_array(test_image)/255 # convert image to np array and normalize
test_image = np.expand_dims(test_image, axis = 0) # change dimention 3D to 4D

# %%
result = model.predict(test_image) # predict diseased palnt or not
pred = np.argmax(result, axis=1)
print(pred)
# Out:
# 1/1 [==============================] - 0s 24ms/step
# [3]
